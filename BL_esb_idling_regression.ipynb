# %%
# import packages
import numpy as np
import pandas as pd
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
# loading the data
df = pd.read_csv('esb_day_level.csv')
df.head()
# Out:
#    vehicle_day_id Region     Fleet Vehicle ID        Date       dist  \
# 0               4     NC  NC1 Lion      EV053   9/24/2021   6.265156
# 1               5     NC  NC1 Lion      EV053  11/26/2021  19.925346
# 2               6     NC  NC1 Lion      EV053   5/26/2022   8.562315
# 3               8     NC  NC1 Lion      EV055   12/3/2021   7.036539
# 4               9     NC  NC1 Lion      EV055   3/23/2022  13.029160
#
#     runtime  idling_time  idling_mins  driving_time        SOC      energy  \
# 0  0.566389     0.001667     0.100000      0.564722  16.008713   33.618298
# 1  1.511944     0.101111     6.066667      1.410833  71.075314  149.258159
# 2  0.614722     0.025833     1.550000      0.588889  19.634705   41.232881
# 3  0.915833     0.071667     4.300000      0.844167  16.979738   35.657451
# 4  0.647778     0.098611     5.916667      0.549167  27.995041   58.789586
#
#         temp       tdiff  over65       ptemp      speed  Efficiency    Heater  \
# 0  99.248000      34.248       1      34.248  11.089115    5.365916  electric
# 1  45.842000     -19.158       0           0   9.504779    7.490869  electric
# 2  74.078047  9.07804692       1  9.07804692   8.664240    4.815623  electric
# 3  50.192000     -14.808       0           0   7.929321    5.067470  electric
# 4  66.002000       1.002       1       1.002  23.714858    4.512155  electric
#
#    elec_heat  region_NC  region_SC  region_RM
# 0          1          1          0          0
# 1          1          1          0          0
# 2          1          1          0          0
# 3          1          1          0          0
# 4          1          1          0          0

# %%
len(df)
# Out:
# 2980

# %%
df['Region'].unique()
# Out:
# array(['NC', 'SC', 'RM', 'GL'], dtype=object)

# %% [markdown]
# # Data Cleaning

# %%
#drop unnecessary columns
cleaned_df = df.drop(['vehicle_day_id', 'Region', 'Fleet', 'Date', 'Heater'], axis=1)

# %%
#drop aberrant rows: e.g. SOC > 100%

# %%
#cleaned_df[cleaned_df['SOC'] > 100]

# %%
rs = np.random.RandomState(0)
df = pd.DataFrame(rs.rand(10, 10))
corr = cleaned_df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_cfe70_row0_col0, #T_cfe70_row1_col1, #T_cfe70_row2_col2, #T_cfe70_row2_col3, #T_cfe70_row3_col2, #T_cfe70_row3_col3, #T_cfe70_row4_col4, #T_cfe70_row5_col5, #T_cfe70_row6_col6, #T_cfe70_row7_col7, #T_cfe70_row8_col8, #T_cfe70_row9_col9, #T_cfe70_row10_col10, #T_cfe70_row11_col11, #T_cfe70_row12_col12, #T_cfe70_row13_col13, #T_cfe70_row14_col14 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_cfe70_row0_col1 {
#   background-color: #e67259;
#   color: #f1f1f1;
# }
# #T_cfe70_row0_col2, #T_cfe70_row0_col3, #T_cfe70_row8_col11 {
#   background-color: #edd1c2;
#   color: #000000;
# }
# #T_cfe70_row0_col4 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_cfe70_row0_col5, #T_cfe70_row5_col6, #T_cfe70_row6_col5 {
#   background-color: #d24b40;
#   color: #f1f1f1;
# }
# #T_cfe70_row0_col6 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_cfe70_row0_col7, #T_cfe70_row12_col1 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_cfe70_row0_col8 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_cfe70_row0_col9 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_cfe70_row0_col10, #T_cfe70_row0_col11, #T_cfe70_row0_col12, #T_cfe70_row1_col8, #T_cfe70_row2_col7, #T_cfe70_row2_col8, #T_cfe70_row2_col9, #T_cfe70_row2_col11, #T_cfe70_row3_col7, #T_cfe70_row3_col8, #T_cfe70_row3_col9, #T_cfe70_row3_col11, #T_cfe70_row11_col1, #T_cfe70_row11_col2, #T_cfe70_row11_col3, #T_cfe70_row12_col0, #T_cfe70_row12_col4, #T_cfe70_row12_col5, #T_cfe70_row12_col6, #T_cfe70_row12_col13, #T_cfe70_row13_col14 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_cfe70_row0_col13, #T_cfe70_row14_col4 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_cfe70_row0_col14, #T_cfe70_row4_col10 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_cfe70_row1_col0 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_cfe70_row1_col2, #T_cfe70_row1_col3, #T_cfe70_row1_col5, #T_cfe70_row5_col1 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_cfe70_row1_col4, #T_cfe70_row4_col1 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_cfe70_row1_col6, #T_cfe70_row6_col1 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_cfe70_row1_col7, #T_cfe70_row5_col12, #T_cfe70_row6_col12, #T_cfe70_row10_col0 {
#   background-color: #4e68d8;
#   color: #f1f1f1;
# }
# #T_cfe70_row1_col9, #T_cfe70_row6_col8, #T_cfe70_row7_col4 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_cfe70_row1_col10 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_cfe70_row1_col11 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_cfe70_row1_col12 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_cfe70_row1_col13 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_cfe70_row1_col14, #T_cfe70_row11_col14, #T_cfe70_row14_col10 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_cfe70_row2_col0, #T_cfe70_row3_col0 {
#   background-color: #efcfbf;
#   color: #000000;
# }
# #T_cfe70_row2_col1, #T_cfe70_row3_col1 {
#   background-color: #f08a6c;
#   color: #f1f1f1;
# }
# #T_cfe70_row2_col4, #T_cfe70_row3_col4 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_cfe70_row2_col5, #T_cfe70_row3_col5, #T_cfe70_row13_col8 {
#   background-color: #dadce0;
#   color: #000000;
# }
# #T_cfe70_row2_col6, #T_cfe70_row3_col6 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_cfe70_row2_col10, #T_cfe70_row3_col10, #T_cfe70_row14_col8 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_cfe70_row2_col12, #T_cfe70_row3_col12, #T_cfe70_row14_col13 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_cfe70_row2_col13, #T_cfe70_row3_col13 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_cfe70_row2_col14, #T_cfe70_row3_col14, #T_cfe70_row4_col13, #T_cfe70_row14_col0 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_cfe70_row4_col0 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_cfe70_row4_col2, #T_cfe70_row4_col3, #T_cfe70_row13_col7 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_cfe70_row4_col5 {
#   background-color: #e9785d;
#   color: #f1f1f1;
# }
# #T_cfe70_row4_col6, #T_cfe70_row6_col4 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_cfe70_row4_col7, #T_cfe70_row7_col0, #T_cfe70_row10_col2, #T_cfe70_row10_col3, #T_cfe70_row10_col4 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_cfe70_row4_col8, #T_cfe70_row9_col2, #T_cfe70_row9_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_cfe70_row4_col9, #T_cfe70_row8_col6, #T_cfe70_row14_col6 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_cfe70_row4_col11, #T_cfe70_row7_col1 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_cfe70_row4_col12, #T_cfe70_row8_col14, #T_cfe70_row9_col14, #T_cfe70_row11_col4 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_cfe70_row4_col14 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_cfe70_row5_col0 {
#   background-color: #d0473d;
#   color: #f1f1f1;
# }
# #T_cfe70_row5_col2, #T_cfe70_row5_col3 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_cfe70_row5_col4 {
#   background-color: #e97a5f;
#   color: #f1f1f1;
# }
# #T_cfe70_row5_col7, #T_cfe70_row12_col9, #T_cfe70_row14_col7 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_cfe70_row5_col8 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_cfe70_row5_col9, #T_cfe70_row9_col5 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_cfe70_row5_col10, #T_cfe70_row10_col8 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_cfe70_row5_col11 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_cfe70_row5_col13, #T_cfe70_row10_col7 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_cfe70_row5_col14, #T_cfe70_row9_col10, #T_cfe70_row10_col9 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_cfe70_row6_col0 {
#   background-color: #e57058;
#   color: #f1f1f1;
# }
# #T_cfe70_row6_col2, #T_cfe70_row6_col3 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_cfe70_row6_col7, #T_cfe70_row14_col12 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_cfe70_row6_col9, #T_cfe70_row9_col6, #T_cfe70_row11_col9 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_cfe70_row6_col10, #T_cfe70_row10_col6 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_cfe70_row6_col11, #T_cfe70_row14_col5 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_cfe70_row6_col13 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_cfe70_row6_col14 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_cfe70_row7_col2, #T_cfe70_row7_col3, #T_cfe70_row10_col1 {
#   background-color: #5e7de7;
#   color: #f1f1f1;
# }
# #T_cfe70_row7_col5, #T_cfe70_row11_col5 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_cfe70_row7_col6, #T_cfe70_row9_col8 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_cfe70_row7_col8 {
#   background-color: #f08b6e;
#   color: #f1f1f1;
# }
# #T_cfe70_row7_col9 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_cfe70_row7_col10 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_cfe70_row7_col11 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_cfe70_row7_col12, #T_cfe70_row13_col5 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_cfe70_row7_col13 {
#   background-color: #f5c2aa;
#   color: #000000;
# }
# #T_cfe70_row7_col14 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_cfe70_row8_col0, #T_cfe70_row10_col5 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_cfe70_row8_col1 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_cfe70_row8_col2, #T_cfe70_row8_col3, #T_cfe70_row9_col1 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_cfe70_row8_col4 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_cfe70_row8_col5 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_cfe70_row8_col7 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_cfe70_row8_col9 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_cfe70_row8_col10, #T_cfe70_row12_col7 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_cfe70_row8_col12 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_cfe70_row8_col13 {
#   background-color: #efcebd;
#   color: #000000;
# }
# #T_cfe70_row9_col0 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_cfe70_row9_col4 {
#   background-color: #a2c1ff;
#   color: #00000

# %%
##correlation of every feature with indepdent variable of idling_mins
##runtime is the strongest correlated feature with idling_mins
#cleaned_df.corr()['idling_mins']

# %%
##correlation of every feature with dependent variable of energy
#cleaned_df.corr()['energy']

# %%
#types of buses in the dataset
cleaned_df['Vehicle ID'].unique()
# Out:
# array(['EV053', 'EV055', 'EV056', 'EV057', 'EV058', 'EV059', 'EV060',
#        'EV054', 'EV061', 'EV062', 'EV063', 'EV064', 'INTL01', 'INTL02',
#        'INTL03', 'INTL04', 'INTL05', 'INTL06', 'INTL07', 'INTL08',
#        'INTL09', 'INTL10', 'BLBR01', 'BLBR02', 'BLBR03', 'EV146', 'EV170',
#        'EV171', 'EV172', 'EV173'], dtype=object)

# %%
cleaned_df['Vehicle ID'].unique()

# %%
cleaned_df['dist'].describe()
# Out:
# count    2980.000000
# mean       60.534678
# std        40.106137
# min         5.003363
# 25%        27.402926
# 50%        56.000000
# 75%        84.000000
# max       205.000000
# Name: dist, dtype: float64

# %%
#all variables that are not correlated with idling_time = dist, over65, elec_heat, region_NC, region_SC, region_RM

# %% [markdown]
# # Base Regression

# %%
#don't include region_RM since that is serving as the 
model = smf.ols(formula='energy ~  dist + idling_mins + over65 + elec_heat + region_NC + region_SC + idling_percentage', data=cleaned_df).fit()
# # model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 energy   R-squared:                       0.823
# Model:                            OLS   Adj. R-squared:                  0.822
# Method:                 Least Squares   F-statistic:                     1707.
# Date:                Wed, 07 Feb 2024   Prob (F-statistic):               0.00
# Time:                        15:37:21   Log-Likelihood:                -11720.
# No. Observations:                2581   AIC:                         2.346e+04
# Df Residuals:                    2573   BIC:                         2.350e+04
# Df Model:                           7
# Covariance Type:            nonrobust
# =====================================================================================
#                         coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------
# Intercept           -48.4879      2.223    -21.810      0.000     -52.847     -44.128
# dist                  1.4970      0.019     77.797      0.000       1.459       1.535
# idling_mins           0.1570      0.017      9.233      0.000       0.124       0.190
# over65               -3.1252      0.975     -3.206      0.001      -5.036      -1.214
# elec_heat            46.1193      2.644     17.444      0.000      40.935      51.304
# region_NC            28.0575      2.881      9.737      0.000      22.407      33.708
# region_SC            32.1498      2.708     11.873      0.000      26.840      37.460
# idling_percentage   -26.3237      2.503    -10.517      0.000     -31.232     -21.416
# ==============================================================================
# Omnibus:                      626.132   Durbin-Watson:                   0.728
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2444.364
# Skew:                           1.143   Prob(JB):                         0.00
# Kurtosis:                       7.184   Cond. No.                         768.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ## Interpretation: this regression has a strong R^2 of 0.82. All of the variables are significant.

# %% [markdown]
# ## for each unit increase in idling minutes (1 minute idled), the energy usage of the battery inceases by .15 kWh

# %% [markdown]
# # Using New Features in Regression

# %%
cleaned_df['SOC'].describe()
# Out:
# count    2526.000000
# mean       50.314264
# std        27.523115
# min         0.950443
# 25%        29.038793
# 50%        48.352475
# 75%        68.400000
# max       265.600000
# Name: SOC, dtype: float64

# %%
cleaned_df['Efficiency'].describe()
# Out:
# count    2581.000000
# mean        1.942760
# std         0.895594
# min         0.306302
# 25%         1.496239
# 50%         1.861605
# 75%         2.255526
# max        16.328469
# Name: Efficiency, dtype: float64

# %%
##engineering new features
#create a new column called idling percentage
cleaned_df['idling_percentage'] = (cleaned_df['idling_time'] / cleaned_df['runtime'])
#add a categorical column where 
cleaned_df.loc[cleaned_df['idling_percentage'] > 0.5, 'idling_more_than_half'] = 1
cleaned_df.loc[cleaned_df['idling_percentage'] <= 0.5, 'idling_more_than_half'] = 0
#create a new column for energy per mile
cleaned_df.loc[cleaned_df['Efficiency'] > 1.94, 'efficency_more_than_mean'] = 1
cleaned_df.loc[cleaned_df['Efficiency'] <= 1.94, 'efficency_more_than_mean'] = 0
#create a new column for SOC more than 1/2
cleaned_df.loc[cleaned_df['SOC'] > 50, 'soc_more_than_half'] = 1
cleaned_df.loc[cleaned_df['SOC'] <= 50, 'soc_more_than_half'] = 0
cleaned_df.head()
# Out:
#   Vehicle ID       dist   runtime  idling_time  idling_mins  driving_time  \
# 0      EV053   6.265156  0.566389     0.001667     0.100000      0.564722
# 1      EV053  19.925346  1.511944     0.101111     6.066667      1.410833
# 2      EV053   8.562315  0.614722     0.025833     1.550000      0.588889
# 3      EV055   7.036539  0.915833     0.071667     4.300000      0.844167
# 4      EV055  13.029160  0.647778     0.098611     5.916667      0.549167
#
#          SOC      energy       temp       tdiff  over65       ptemp  \
# 0  16.008713   33.618298  99.248000      34.248       1      34.248
# 1  71.075314  149.258159  45.842000     -19.158       0           0
# 2  19.634705   41.232881  74.078047  9.07804692       1  9.07804692
# 3  16.979738   35.657451  50.192000     -14.808       0           0
# 4  27.995041   58.789586  66.002000       1.002       1       1.002
#
#        speed  Efficiency  elec_heat  region_NC  region_SC  region_RM  \
# 0  11.089115    5.365916          1          1          0          0
# 1   9.504779    7.490869          1          1          0          0
# 2   8.664240    4.815623          1          1          0          0
# 3   7.929321    5.067470          1          1          0          0
# 4  23.714858    4.512155          1          1          0          0
#
#    idling_percentage  idling_more_than_half  soc_more_than_half  \
# 0           0.002943                    0.0                 0.0
# 1           0.066875                    0.0                 1.0
# 2           0.042024                    0.0                 0.0
# 3           0.078253                    0.0                 0.0
# 4           0.152230                    0.0                 0.0
#
#    efficency_more_than_mean
# 0                       1.0
# 1                       1.0
# 2                       1.0
# 3                       1.0
# 4                       1.0

# %%
cleaned_df['idling_more_than_half'].value_counts()
# Out:
# 0.0    2750
# 1.0     230
# Name: idling_more_than_half, dtype: int64

# %%
cleaned_df['soc_more_than_half'].value_counts()
# Out:
# 0.0    1307
# 1.0    1219
# Name: soc_more_than_half, dtype: int64

# %%
#don't include region_RM since that is serving as the 
model = smf.ols(formula='energy ~  dist + idling_mins + over65 + elec_heat + region_NC + region_SC + idling_percentage + soc_more_than_half', data=cleaned_df).fit()
# # model summary
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 energy   R-squared:                       0.844
# Model:                            OLS   Adj. R-squared:                  0.843
# Method:                 Least Squares   F-statistic:                     1697.
# Date:                Wed, 07 Feb 2024   Prob (F-statistic):               0.00
# Time:                        16:00:49   Log-Likelihood:                -11306.
# No. Observations:                2524   AIC:                         2.263e+04
# Df Residuals:                    2515   BIC:                         2.268e+04
# Df Model:                           8
# Covariance Type:            nonrobust
# ======================================================================================
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# Intercept            -36.9137      2.237    -16.503      0.000     -41.300     -32.528
# dist                   1.2063      0.028     43.044      0.000       1.151       1.261
# idling_mins            0.1293      0.016      7.862      0.000       0.097       0.162
# over65                -2.7961      0.920     -3.040      0.002      -4.600      -0.992
# elec_heat             35.8142      2.553     14.027      0.000      30.808      40.821
# region_NC             29.8567      2.718     10.987      0.000      24.528      35.186
# region_SC             34.2374      2.561     13.368      0.000      29.215      39.260
# idling_percentage    -26.5171      2.361    -11.233      0.000     -31.146     -21.888
# soc_more_than_half    24.6755      1.420     17.372      0.000      21.890      27.461
# ==============================================================================
# Omnibus:                      620.120   Durbin-Watson:                   0.777
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2485.343
# Skew:                           1.149   Prob(JB):                         0.00
# Kurtosis:                       7.284   Cond. No.                         746.
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# # Plotting Variables Against Energy
